# %% [markdown]
# <a href="https://colab.research.google.com/github/ad-ris/Visualisasi/blob/main/Visualisasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **interpretasi**

# %% [markdown]
# ![Annotation 2021-11-02 082007.png](data:image/png;base64,...)

# %% [markdown]
# ![download (1).png](data:image/png;base64,...)

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# Dilihat dari 2 gambar diatas bisa dilihat jika "open", "indonesia", "denmark", dan "french" menduduki peringkat penggunaan kata paling banyak. Ini menandakan kata-kata itu sedang ramai dibicarakan , orang-orang antusias pada event bulutangkis yang sedang berlangsung seperti indonesia open, denmark open, dan french open.
